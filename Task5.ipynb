# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('globalterrorismdb_0718dist.csv', encoding = "ISO-8859-1", low_memory=False)
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
pd.options.display.max_columns = None
data.sample(6)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 92770   200907140013   2009       7    14        NaN         0        NaN
# 175038  201705200050   2017       5    20        NaN         0        NaN
# 168616  201610280019   2016      10    28        NaN         0        NaN
# 24135   198501040004   1985       1     4        NaN         0        NaN
# 39662   198909110022   1989       9    11        NaN         0        NaN
# 57620   199410260003   1994      10    26        NaN         0        NaN
#
#         country   country_txt  region                  region_txt  \
# 92770       167        Russia       9              Eastern Europe
# 175038      200         Syria      10  Middle East & North Africa
# 168616       92         India       6                  South Asia
# 24135        45      Colombia       3               South America
# 39662       183  South Africa      11          Sub-Saharan Africa
# ...

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
data_for_analysis = data.loc[:,['iyear', 'imonth', 'iday','country_txt', 'region_txt','city', 'latitude', 'longitude', 
'attacktype1_txt','targtype1_txt','target1','targsubtype1_txt','corp1','gname','motive','weaptype1_txt','nkill','nwound','success','summary']]
data_for_analysis.sample(5)
# Out:
#         iyear  imonth  iday  country_txt                  region_txt  \
# 129848   2014       4     5  Afghanistan                  South Asia
# 159754   2016       3     7        Egypt  Middle East & North Africa
# 105573   2012       2     4  Afghanistan                  South Asia
# 89180    2008      10    25         Iraq  Middle East & North Africa
# 174096   2017       4    20         Iraq  Middle East & North Africa
#
#                          city   latitude  longitude  \
# 129848  Shirin Tagab district  36.238384  64.864419
# 159754                  Arish  31.126646  33.800865
# 105573        Sangin district  32.073333  64.833889
# 89180                   Mosul  36.354145  43.143570
# 174096                Hawijah  35.326122  43.780811
#
#                     attacktype1_txt                targtype1_txt  \
# 129848            Bombing/Explosion         Government (General)
# 159754            Bombing/Explosion                     Military
# ...

# %%
def fill_zeros(columns):
    for i in columns:
        data_for_analysis[i] = np.where(data_for_analysis[i] == 0,1, data_for_analysis[i])
fill_zeros(['imonth','iday'])

# %%
data_for_analysis['date'] = [(str(data_for_analysis['iyear'][i]) + '-' + str(data_for_analysis['imonth'][i]) +'-' + str(data_for_analysis['iday'][i])) for i in np.arange(data_for_analysis['iday'].shape[0]) ]
data_for_analysis['date']
# Out:
# 0           1970-7-2
# 1           1970-1-1
# 2           1970-1-1
# 3           1970-1-1
# 4           1970-1-1
#              ...
# 181686    2017-12-31
# 181687    2017-12-31
# 181688    2017-12-31
# 181689    2017-12-31
# 181690    2017-12-31
# Name: date, Length: 181691, dtype: object

# %%
data_for_analysis['date'] = pd.to_datetime(data_for_analysis['date'])

# %%
data_for_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   country_txt       181691 non-null  object
#  4   region_txt        181691 non-null  object
#  5   city              181257 non-null  object
#  6   latitude          177135 non-null  float64
#  7   longitude         177134 non-null  float64
#  8   attacktype1_txt   181691 non-null  object
#  9   targtype1_txt     181691 non-null  object
#  10  target1           181055 non-null  object
#  11  targsubtype1_txt  171318 non-null  object
#  12  corp1             139141 non-null  object
#  13  gname             181691 non-null  object
#  14  motive            50561 non-null   object
#  15  weaptype1_txt     181691 non-null  object
# ...

# %%
data_for_analysis.describe()
# Out:
#                iyear         imonth           iday       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467387      15.510548      23.498343
# std        13.259430       3.388110       8.805691      18.569242
# min      1970.000000       1.000000       1.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude          nkill         nwound        success
# count  1.771340e+05  171378.000000  165380.000000  181691.000000
# mean  -4.586957e+02       2.403272       3.167668       0.889598
# std    2.047790e+05      11.545741      35.949392       0.313391
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# Questions to be answered:
# 1. what was the most devastating terrorist attack?
# 2. What year had the most terror attacks attempts/ victims?
# 3. what is the country/ target with the most terrorist attacks/ victims?
# 4. what is the most used attacking method each year?
# 5. which terrorist group had the most terrorist attacks attempts?

# %% [markdown]
# Question no. 1: what was the most devastating terrorist attack each year?

# %%
year_nkill =data_for_analysis.loc[:,['iyear','nkill']].groupby('iyear').max()

# %%
most_kills = pd.DataFrame(columns=data_for_analysis.columns.values)

# %%
for index, row in year_nkill.iterrows():
    most_kills = pd.concat([most_kills,data_for_analysis[(data_for_analysis['iyear'] == index) & (data_for_analysis['nkill'] == row[0])]])

# %%
most_kills.sample(5)
# Out:
#       iyear imonth iday    country_txt                   region_txt  \
# 84010  2007      8   14           Iraq   Middle East & North Africa
# 11636  1980      8   15    El Salvador  Central America & Caribbean
# 59037  1995      4   19  United States                North America
# 76347  2004      3   21          Nepal                   South Asia
# 39781  1989      9   19          Niger           Sub-Saharan Africa
#
#                    city   latitude  longitude    attacktype1_txt  \
# 84010         Qahtaniya  36.202354  41.687168  Bombing/Explosion
# 11636         Suchitoto  13.933732 -89.025836      Armed Assault
# 59037     Oklahoma City  35.472015 -97.520354  Bombing/Explosion
# 76347  Dhading district  27.959441  84.895897      Armed Assault
# 39781    Goure district  16.864946  11.953771  Bombing/Explosion
#
#                      targtype1_txt  \
# 84010  Private Citizens & Property
# 11636                     Military
# 59037         Government (General)
# ...

# %% [markdown]
# Question no.2 : What year had the most terror attacks attempts/ victims?

# %%
most_kills[most_kills['nkill'] == most_kills['nkill'].max()]
# Out:
#        iyear imonth iday country_txt                  region_txt    city  \
# 133518  2014      6   12        Iraq  Middle East & North Africa  Tikrit
#
#          latitude  longitude              attacktype1_txt targtype1_txt  \
# 133518  34.621521  43.668377  Hostage Taking (Kidnapping)      Military
#
#          target1                                   targsubtype1_txt  \
# 133518  Soldiers  Military Personnel (soldiers, troops, officers...
#
#                      corp1                                        gname  \
# 133518  Iraqi Armed Forces  Islamic State of Iraq and the Levant (ISIL)
#
#                                                    motive weaptype1_txt  \
# 133518  The Islamic State of Iraq and the Levant (ISIL...      Firearms
#
#          nkill nwound success  \
# 133518  1570.0    NaN       1
#
#                                                   summary                 date
# 133518  06/12/2014: Assailants abducted approximately ...  2014-06-12 00:00:00

# %% [markdown]
# Question no.3 : 3. what is the country/ target with the most terrorist attacks/ victims?

# %%
country_attacks = data_for_analysis.pivot_table(index='country_txt', columns='iyear', aggfunc='count')

# %%
country_attacks['attacktype1_txt'][1970][country_attacks['attacktype1_txt'][1970] == country_attacks['attacktype1_txt'][1970].max()]
# Out:
# country_txt
# United States    468.0
# Name: 1970, dtype: float64

# %%
country_dict = {}
for i in range(1970,2018):
    try:
        dict_series = country_attacks['attacktype1_txt'][i][country_attacks['attacktype1_txt'][i] == country_attacks['attacktype1_txt'][i].max()]
        country_dict[i] = [dict_series.index[0],dict_series[0]]
    except KeyError: continue
pd.DataFrame(country_dict)
# Out:
#             1970           1971            1972            1973  \
# 0  United States  United States  United Kingdom  United Kingdom
# 1          468.0          247.0           292.0           189.0
#
#              1974            1975            1976   1977   1978         1979  \
# 0  United Kingdom  United Kingdom  United Kingdom  Italy  Italy  El Salvador
# 1           203.0           194.0           194.0  308.0  277.0        326.0
#
#           1980         1981         1982   1983   1984         1985   1986  \
# 0  El Salvador  El Salvador  El Salvador   Peru   Peru  El Salvador   Peru
# 1        710.0        664.0        537.0  536.0  592.0        436.0  568.0
#
#     1987      1988   1989   1990   1991      1992    1994      1995      1996  \
# 0   Peru  Colombia   Peru   Peru   Peru  Colombia  Turkey  Pakistan  Colombia
# 1  627.0     427.0  630.0  495.0  658.0     523.0   300.0     666.0     409.0
#
# ...

# %% [markdown]
# 4. what is the most used attacking method each year?

# %%
type_attacks = data_for_analysis.pivot_table(index='attacktype1_txt', columns='iyear', aggfunc='count')

# %%
type_dict = {}
for i in range(1970,2018):
    try:
        dict_series = type_attacks['city'][i][type_attacks['city'][i] == type_attacks['city'][i].max()]
        type_dict[i] = [dict_series.index[0],dict_series[0]]
    except KeyError: continue
pd.DataFrame(type_dict)
# Out:
#                 1970               1971           1972           1973  \
# 0  Bombing/Explosion  Bombing/Explosion  Assassination  Assassination
# 1              333.0              239.0          265.0          164.0
#
#                 1974               1975               1976               1977  \
# 0  Bombing/Explosion  Bombing/Explosion  Bombing/Explosion  Bombing/Explosion
# 1              285.0              370.0              419.0              635.0
#
#                 1978               1979               1980               1981  \
# 0  Bombing/Explosion  Bombing/Explosion  Bombing/Explosion  Bombing/Explosion
# 1              644.0             1058.0              997.0             1082.0
#
#                 1982               1983               1984               1985  \
# 0  Bombing/Explosion  Bombing/Explosion  Bombing/Explosion  Bombing/Explosion
# 1             1125.0             1246.0             1776.0             1482.0
#
# ...

# %% [markdown]
# Question no.5: which terrorist group had the most terrorist attacks attempts?

# %%
terror_group = data_for_analysis.pivot_table(index='gname', columns='iyear', aggfunc='count')

# %%
terror_group
# Out:
#                                       attacktype1_txt                      \
# iyear                                            1970 1971 1972 1973 1974
# gname
# 1 May                                             NaN  NaN  NaN  NaN  NaN
# 14 K Triad                                        NaN  NaN  NaN  NaN  NaN
# 14 March Coalition                                NaN  NaN  NaN  NaN  NaN
# 14th of December Command                          NaN  NaN  NaN  NaN  NaN
# 15th of September Liberation Legion               NaN  NaN  NaN  NaN  NaN
# ...                                               ...  ...  ...  ...  ...
# Zulu Miners                                       NaN  NaN  NaN  NaN  NaN
# Zuwar al-Imam Rida                                NaN  NaN  NaN  NaN  NaN
# Zviadists                                         NaN  NaN  NaN  NaN  NaN
# Zwai Tribe                                        NaN  NaN  NaN  NaN  NaN
# leftist guerrillas-Bolivarian militia             NaN  NaN  NaN  NaN  NaN
# ...

# %%
terror_group['attacktype1_txt'][1970][terror_group['attacktype1_txt'][1970] == (terror_group['attacktype1_txt'][1970]).max()]
# Out:
# gname
# Unknown    115.0
# Name: 1970, dtype: float64

# %%
terror_dict = {}
for i in range(1970,2018):
    try:
        dict_series = terror_group['attacktype1_txt'][i][terror_group['attacktype1_txt'][i] == (terror_group['attacktype1_txt'][i]).max()]
        terror_dict[i] = [dict_series.index[0],dict_series[0]]
    except KeyError: continue
pd.DataFrame(terror_dict)
# Out:
#       1970     1971                         1972     1973     1974     1975  \
# 0  Unknown  Unknown  Irish Republican Army (IRA)  Unknown  Unknown  Unknown
# 1    115.0     98.0                        162.0    112.0    115.0    128.0
#
#       1976     1977     1978     1979     1980     1981     1982     1983  \
# 0  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown
# 1    303.0    520.0    499.0    799.0   1217.0   1222.0    998.0    704.0
#
#       1984     1985     1986     1987     1988     1989     1990     1991  \
# 0  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown
# 1   1023.0    684.0    826.0    657.0    977.0   1184.0   1230.0   1388.0
#
#       1992     1994     1995     1996     1997     1998     1999     2000  \
# 0  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown  Unknown
# 1   1822.0   1464.0   1572.0   1592.0   1958.0    463.0    640.0    710.0
#
# ...

# %%
data_for_analysis['gname'].value_counts().index.values[1]
# Out:
# 'Taliban'

# %%
list_of_top_groups = []
filter = data_for_analysis['gname'].value_counts()
for i in filter.index.values:
    if (filter[i] > 1) == True:
        list_of_top_groups.append(i)

# %%
data_cleaned = data_for_analysis[data_for_analysis['gname'].isin(list_of_top_groups)]

# %%
sum(data_cleaned['gname'].value_counts() > data_cleaned['gname'].value_counts().quantile(0.99))
# Out:
# 19
